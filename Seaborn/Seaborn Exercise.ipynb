# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Plot 1

# %%
sns.jointplot(x='fare', y='age', data=titanic)

# %% [markdown]
# # Plot 2

# %%
sns.distplot(titanic['fare'], kde=False, color='red')

# %% [markdown]
# # Plot 3

# %%
sns.boxplot(x='class', y='age', data=titanic)

# %% [markdown]
# # Plot 4

# %%
sns.swarmplot(x='class', y='age', data=titanic)
# Out:
# D:\Programme\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# D:\Programme\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# # Plot 5

# %%
sns.countplot(data=titanic, x='sex')

# %% [markdown]
# # Plot 6

# %%
sns.heatmap(titanic.corr())

# %% [markdown]
# # Plot 7

# %%
g = sns.FacetGrid(titanic, col="sex")
g.map(plt.hist, 'age')
